# %%
import earthaccess as ea
results = ea.search_data(
    short_name='ATL06',
    bounding_box=(-10, 20, 10, 50),
    temporal=("1999-02", "2019-03"),
    count=10,
)
results
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 import earthaccess as ea
# ----> 2 results = ea.search_data(
#       3     short_name='ATL06',
#       4     bounding_box=(-10, 20, 10, 50),
#       5     temporal=("1999-02", "2019-03"),
#       6     count=10,
#       7 )
#       8 results
#
# File ~/Projects/earthaccess-dev/earthaccess/earthaccess/api.py:280, in search_data(count, **kwargs)
#     278 logger.info(f"Granules found: {granules_found}")
#     279 if count > 0:
# --> 280     return query.get(count)
#     281 return query.get_all()
#
# File ~/Projects/earthaccess-dev/earthaccess/earthaccess/search.py:493, in DataGranules.get(self, limit)
#     490 response = get_results(self.session, self, limit)
#     491 cloud = len(response) > 0 and self._is_cloud_hosted(response[0])
# --> 493 return Results(
# ...
